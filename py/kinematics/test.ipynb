# %%
import runner

# %%
runner.run('./config/use_RMPfromGDS_test.yaml')
# Out:
# 制御器セット中...
# セット完了
# セット時間 =  0.0
#
# 環境セット中...
# {'name': 'static', 'center': [[0.3, -0.75, 1]]}
# セット完了
# セット時間 =  0.008001089096069336
#
# シミュレーション実行中...
# c:\Users\Yoshi\source_control_study\manipulator_dynamics\py\kinematics\new.py:63: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   z = np.array([
# t =  2.04
# t =  2.04
# t =  2.17
# t =  2.24
# t =  2.56
# t =  2.62
# t =  2.69
# t =  2.69
# t =  2.85
# t =  2.93
# t =  4.20
# t =  4.29
# t =  4.39
# t =  4.39
# t =  4.56
# t =  4.64
# t =  6.07
# t =  6.07
# t =  6.24
# t =  6.33
# t =  6.77
# t =  6.85
# t =  6.95
# t =  6.95
# t =  8.30
# t =  8.37
# t =  8.45
# t =  8.45
# t =  8.61
# t =  8.69
# t =  10.04
# t =  10.14
# t =  10.14
# t =  10.32
# t =  10.41
# t =  10.87
# t =  10.96
# t =  12.03
# ...

# %%
pwd()
# Out:
# 'c:\\Users\\Yoshi\\source_control_study\\manipulator_dynamics\\py\\kinematics'
